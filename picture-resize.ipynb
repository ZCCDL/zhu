# %%
import numpy as np
import cv2
import glob
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def imgresize(path1,path2,filename):
    img=cv2.imread(im)
    RED=[0,0,0]
    xpad=(1600-int(img.shape[0]))/2
    ypad=(1600-int(img.shape[1]))/2
    img2 = cv2.copyMakeBorder(img, xpad,xpad,ypad,ypad, cv2.BORDER_CONSTANT, value=RED)
    cv2.imwrite(path2+filename,img2)

# %%
import os
#path='/home/user/zhu/train/'
#pathh='/home/user/zhu/train1/'
path='/home/user/zhu/new data/vali/'
pathh='/home/user/zhu/val1/'
listdir=os.listdir(path)
for id in listdir:
    os.mkdir(pathh+id)
    path1=pathh+id+'/'   
    #for idx in os.listdir(path+id):
    for im in glob.glob(path+id+'/*.jpeg'):
           
        imgresize(im,path1,im.split('/')[7])

# %%
path='/home/user/zhu/train/'
pa='/home/user/zhu/train/12'
listd=os.listdir(pa)
#print listd
a=cv2.imread(pa+'/'+listd[4])
#plt.imshow(a)
for im in glob.glob(path+str(4)+'/*.jpeg'):
    print im.split('/')[6]
# Out:
# 1202.jpeg
# 310.jpeg
# 1434.jpeg
# 403.jpeg
# 278.jpeg
# 193.jpeg
# 233.jpeg
# 4.jpeg
# 1431.jpeg
# 479.jpeg
# 1291.jpeg
# 1138.jpeg
# 3.jpeg
# 507.jpeg
# 1535.jpeg
# 1375.jpeg
# 1116.jpeg
# 1121.jpeg
# 1265.jpeg
# 1233.jpeg
# 129.jpeg
# 96.jpeg
# 1389.jpeg
# 434.jpeg
# 1645.jpeg
# 794.jpeg
# 1076.jpeg
# 1437.jpeg
# 874.jpeg
# 944.jpeg
# 1492.jpeg
# 336.jpeg
# 1642.jpeg
# 1013.jpeg
# 638.jpeg
# 1277.jpeg
# 968.jpeg
# 1103.jpeg
# 1506.jpeg
# 1635.jpeg
# 984.jpeg
# 1075.jpeg
# 1100.jpeg
# 1016.jpeg
# 372.jpeg
# 1102.jpeg
# 512.jpeg
# 911.jpeg
# 80.jpeg
# 1083.jpeg
# 82.jpeg
# 1374.jpeg
# 837.jpeg
# 228.jpeg
# 707.jpeg
# 1618.jpeg
# 1452.jpeg
# 865.jpeg
# 1699.jpeg
# 1337.jpeg
# 1439.jpeg
# 698.jpeg
# 92.jpeg
# 660.jpeg
# 1646.jpeg
# 136.jpeg
# 379.jpeg
# 117.jpeg
# 144.jpeg
# 69.jpeg
# 574.jpeg
# 1682.jpeg
# 668.jpeg
# 162.jpeg
# 536.jpeg
# 362.jpeg
# 627.jpeg
# 1195.jpeg
# 1450.jpeg
# 822.jpeg
# 1041.jpeg
# 70.jpeg
# 569.jpeg
# 60.jpeg
# 1362.jpeg
# 659.jpeg
# 1395.jpeg
# 359.jpeg
# ...
